# %%
import random 

choices=['rock','paper','scissor']

while True:
  user_choice=input("\n Enter your choice or exit to enter ").lower()

  computer_choice=random.choice(choices)


  if user_choice=='exit':
    break
  elif user_choice not in choices:
    print("enter valid choice")

  elif ( if user_choice=='rock' and computer_choice=='scissor') or
