# %% [markdown]
# create a function that takes the list as the argument and filter out the all the data types and store only the number type in the another list

# %%
# list1=[1,2,3,"sushant",True,5.4,5+4j]
# numlist=[]
# for i in list1:
#   if type(i)==int or type(i)==float:
#     numlist.append(i)

# print(numlist)
# Out:
# [1, 2, 3, 5.4]

# %%
def filternumbers(lst):
  numlist=[]
  for i in lst:
    if type(i)==int or type(i)==float:
      numlist.append(i)
      
  print(numlist)

filternumbers([1,2,3,"sushant",True,5.4,5+4j])
# Out:
# [1, 2, 3, 5.4]

# %%
# lambda functions
temp=lambda c: c*9/5 +32
temp(37.5)
# Out:
# 99.5

# %%
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
  for j in range(i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
