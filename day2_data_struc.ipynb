# %% [markdown]
# Dictionary in python

# %%
dict={}
dict["name"]="sushant"
dict["age"]=24
dict["education"]="BCA"
dict
# Out:
# {'name': 'sushant', 'age': 24, 'education': 'BCA'}

# %%
print(type(dict))
# Out:
# <class 'dict'>

# %%
type(dict)
# Out:
# dict

# %%
len(dict)
# Out:
# 3

# %%
dict.keys()
# Out:
# dict_keys(['name', 'age', 'education'])

# %%
dict.values()
# Out:
# dict_values(['sushant', 24, 'BCA'])

# %%
dict.items()
# Out:
# dict_items([('name', 'sushant'), ('age', 24), ('education', 'BCA')])

# %%
for item in dict.items():
  print(item)
# Out:
# ('name', 'sushant')
# ('age', 24)
# ('education', 'BCA')

# %%
for key,value in dict.items():
  print(f"{key}:{value}")
# Out:
# name:sushant
# age:24
# education:BCA

# %%
dict.get("name")
# Out:
# 'sushant'

# %%
dict.get("age")
# Out:
# 24

# %%
dict.get("sushant")

# %%
dict.pop("name")
# Out:
# 'sushant'

# %%
dict
# Out:
# {'age': 24, 'education': 'BCA'}

# %%
dict["name"]="sushant"

# %%
copied_dict=dict.copy()
copied_dict
# Out:
# {'age': 24, 'education': 'BCA', 'name': 'sushant'}

# %%
copied_dict["age"]=23

# %%
copied_dict
# Out:
# {'age': 23, 'education': 'BCA', 'name': 'sushant'}

# %%
dict
# Out:
# {'age': 24, 'education': 'BCA', 'name': 'sushant'}

# %%
dict2=dict
dict2
# Out:
# {'age': 24, 'education': 'BCA', 'name': 'sushant'}

# %%
dict2["age"]=25
dict2
# Out:
# {'age': 25, 'education': 'BCA', 'name': 'sushant'}

# %%
dict
# Out:
# {'age': 25, 'education': 'BCA', 'name': 'sushant'}

# %%
print("yes") if dict.get("name")=="sushant1" else print("False")
# Out:
# False

# %%
"sushant" in dict.items()
# Out:
# False

# %%
"sushant" in dict.values()
# Out:
# True

# %%
"name" in dict.keys()
# Out:
# True

# %%
dict.items()
# Out:
# dict_items([('age', 25), ('education', 'BCA'), ('name', 'sushant')])

# %%
('age',25) in dict.items()
# Out:
# True

# %%
25 in dict
# Out:
# False

# %%
25 in dict.values()
# Out:
# True
