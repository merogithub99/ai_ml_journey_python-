# %%
class Father:
  def __init__(self,property):
    self.property=property

  def sonName(self):
    return "sushant from dad method"

# %%
class Mother:
  def __init__(self,property):
    self.property=property

  def sonName(self):
    return "sushant from mom "

# %%
class Child(Father,Mother):
  pass

# %%
c1=Child(100000)

# %%
c1.sonName()
# Out:
# 'sushant'

# %%
f=Father(200000)

# %%
f.sonName()
# Out:
# 'sushant from dad method'

# %%
m=Mother(500)

# %%
m.property
# Out:
# 500

# %%
m.sonName()
# Out:
# 'sushant from mom '
