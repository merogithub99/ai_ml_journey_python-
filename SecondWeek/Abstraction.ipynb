# %%
from abc import ABC,abstractmethod

# %%
class AbstClass(ABC):
  @abstractmethod
  def abMethod1(self):
    pass
  def abMethod2(self):
    return "abs method 2 from the abs class"

# %%
# class A(AbstClass):
#   pass

# %%
a=A()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=A()
#
# TypeError: Can't instantiate abstract class A without an implementation for abstract method 'abMethod1'

# %%
class A(AbstClass):
  def abMethod2(self):
    return super().abMethod1()
  
  def abMethod1(self):
    return "abs method impl in class A ie. child "

# %%
a=A()

# %%
a.abMethod1()
# Out:
# 'abs method impl in class A ie. child '

# %%
a.abMethod2()
